# %%
# ==========================================================
# 1. Imports and environment setup
# ==========================================================
import sys
from pathlib import Path
import numpy as np
from pprint import pprint

# Ensure we can import from the src folder (project root = parent of notebooks/)
PROJECT_ROOT = Path.cwd().parents[0]
sys.path.append(str(PROJECT_ROOT))

from src.data.data_feeder import DataFeeder

# Display settings for cleaner numpy output
np.set_printoptions(precision=3, suppress=True, linewidth=120)

print("🚀 Starting DataFeeder test within notebook...\n")


# ==========================================================
# 2. Helper function for inspecting folds
# ==========================================================
def inspect_folds(folds: dict, description: str):
    """
    Inspect and print the structure and shapes of DataFeeder outputs.
    Each fold contains ((N, C, y), info), where N/C/y are dictionaries
    with keys: 'train', 'val', 'test'.
    """
    print("\n==============================")
    print(f" {description}")
    print("==============================")

    for fold_id, ((N, C, y), info) in folds.items():
        print(f"\n📂 Fold {fold_id}:")
        print("Info:")
        pprint(info)

        def safe_shape(x):
            return None if x is None else x.shape

        # --- Numerical Features ---
        if N is not None:
            print("\nNumerical features:")
            for split in ["train", "val", "test"]:
                print(f"  • {split:<5}: {safe_shape(N[split])}")
        else:
            print("\nNumerical features: None")

        # --- Categorical Features ---
        if C is not None:
            print("\nCategorical features:")
            for split in ["train", "val", "test"]:
                print(f"  • {split:<5}: {safe_shape(C[split])}")
        else:
            print("\nCategorical features: None")

        # --- Targets ---
        print("\nTargets:")
        for split in ["train", "val", "test"]:
            print(f"  • {split:<5}: {safe_shape(y[split])}")
        print(f"  Target mean (train): {np.mean(y['train']):.3f} | (test): {np.mean(y['test']):.3f}")

    print("\n✅ Fold inspection complete.\n")


# ==========================================================
# 3. TEST CASE 1 — PD (classification)
# ==========================================================
print("🧪 Testing PD (classification) dataset — single split (cv=1)")

feeder_pd_single = DataFeeder(
    task="pd",
    dataset="0014.hmeq",    # Replace with a dataset available locally
    test_size=0.2,
    val_size=0.2,
    cv_splits=1,
    seed=42,
    sampling=0.3,           # optional resampling for imbalance
)
folds_pd_single = feeder_pd_single.prepare()
inspect_folds(folds_pd_single, "PD dataset — single split (cv=1)")


print("🧪 Testing PD (classification) dataset — cross-validation (cv=3)")

feeder_pd_cv = DataFeeder(
    task="pd",
    dataset="0014.hmeq",
    test_size=0.2,          # ignored in CV mode
    val_size=0.2,
    cv_splits=3,
    seed=42,
)
folds_pd_cv = feeder_pd_cv.prepare()
inspect_folds(folds_pd_cv, "PD dataset — 3-fold CV")


# ==========================================================
# 4. TEST CASE 2 — LGD (regression)
# ==========================================================
print("🧪 Testing LGD (regression) dataset — single split (cv=1)")

feeder_lgd_single = DataFeeder(
    task="lgd",
    dataset="0001.heloc",   # Replace with a regression dataset you have
    test_size=0.25,
    val_size=0.2,
    cv_splits=1,
    seed=123,
)
folds_lgd_single = feeder_lgd_single.prepare()
inspect_folds(folds_lgd_single, "LGD dataset — single split (cv=1)")


print("🧪 Testing LGD (regression) dataset — cross-validation (cv=3)")

feeder_lgd_cv = DataFeeder(
    task="lgd",
    dataset="0001.heloc",
    test_size=0.25,         # ignored in CV mode
    val_size=0.2,
    cv_splits=3,
    seed=123,
)
folds_lgd_cv = feeder_lgd_cv.prepare()
inspect_folds(folds_lgd_cv, "LGD dataset — 3-fold CV")


# ==========================================================
# 5. Summary of test results
# ==========================================================
print("\n🎯 Summary of DataFeeder Tests:")
print("- ✅ DataFeeder successfully loaded and preprocessed all datasets.")
print("- ✅ Output structure is fully TALENT-compatible (dicts with train/val/test).")
print("- ✅ Single-split and CV modes both operational.")
print("- ✅ Feature and target shapes verified per split.")
print("- ✅ Target distributions printed for sanity checking.")
print("\n🎉 All DataFeeder tests completed successfully within notebook.\n")
# Out:
# 🚀 Starting DataFeeder test within notebook...
#
# 🧪 Testing PD (classification) dataset — single split (cv=1)
#
# ==============================
#  PD dataset — single split (cv=1)
# ==============================
#
# 📂 Fold 1:
# Info:
# {'n_cat_features': 2, 'n_num_features': 10, 'task_type': 'classification'}
#
# Numerical features:
#   • train: (2536, 10)
#   • val  : (634, 10)
#   • test : (1192, 10)
#
# Categorical features:
#   • train: (2536, 2)
#   • val  : (634, 2)
#   • test : (1192, 2)
#
# Targets:
#   • train: (2536,)
#   • val  : (634,)
#   • test : (1192,)
#   Target mean (train): 0.300 | (test): 0.200
#
# ✅ Fold inspection complete.
#
# 🧪 Testing PD (classification) dataset — cross-validation (cv=3)
#
# ==============================
#  PD dataset — 3-fold CV
# ==============================
#
# 📂 Fold 1:
# Info:
# {'n_cat_features': 2, 'n_num_features': 10, 'task_type': 'classification'}
#
# Numerical features:
#   • train: (3178, 10)
#   • val  : (795, 10)
#   • test : (1987, 10)
#
# Categorical features:
#   • train: (3178, 2)
#   • val  : (795, 2)
#   • test : (1987, 2)
#
# Targets:
#   • train: (3178,)
#   • val  : (795,)
#   • test : (1987,)
#   Target mean (train): 0.199 | (test): 0.200
#
# 📂 Fold 2:
# Info:
# {'n_cat_features': 2, 'n_num_features': 10, 'task_type': 'classification'}
#
# Numerical features:
#   • train: (3178, 10)
#   • val  : (795, 10)
#   • test : (1987, 10)
#
# Categorical features:
#   • train: (3178, 2)
#   • val  : (795, 2)
#   • test : (1987, 2)
#
# Targets:
#   • train: (3178,)
#   • val  : (795,)
#   • test : (1987,)
#   Target mean (train): 0.199 | (test): 0.199
#
# 📂 Fold 3:
# Info:
# {'n_cat_features': 2, 'n_num_features': 10, 'task_type': 'classification'}
#
# Numerical features:
#   • train: (3179, 10)
#   • val  : (795, 10)
#   • test : (1986, 10)
#
# Categorical features:
#   • train: (3179, 2)
#   • val  : (795, 2)
#   • test : (1986, 2)
#
# Targets:
#   • train: (3179,)
#   • val  : (795,)
#   • test : (1986,)
#   Target mean (train): 0.199 | (test): 0.199
#
# ✅ Fold inspection complete.
#
# 🧪 Testing LGD (regression) dataset — single split (cv=1)
#
# ==============================
#  LGD dataset — single split (cv=1)
# ==============================
#
# 📂 Fold 1:
# Info:
# {'n_cat_features': 0, 'n_num_features': 9, 'task_type': 'regression'}
#
# Numerical features:
#   • train: (40738, 9)
#   • val  : (10185, 9)
#   • test : (16975, 9)
#
# Categorical features: None
#
# Targets:
#   • train: (40738,)
#   • val  : (10185,)
#   • test : (16975,)
#   Target mean (train): 0.678 | (test): 0.681
#
# ✅ Fold inspection complete.
#
# 🧪 Testing LGD (regression) dataset — cross-validation (cv=3)
#
# ==============================
#  LGD dataset — 3-fold CV
# ==============================
#
# 📂 Fold 1:
# Info:
# {'n_cat_features': 0, 'n_num_features': 9, 'task_type': 'regression'}
#
# Numerical features:
#   • train: (36212, 9)
#   • val  : (9053, 9)
#   • test : (22633, 9)
#
# Categorical features: None
#
# Targets:
#   • train: (36212,)
#   • val  : (9053,)
#   • test : (22633,)
#   Target mean (train): 0.679 | (test): 0.680
#
# 📂 Fold 2:
# Info:
# {'n_cat_features': 0, 'n_num_features': 9, 'task_type': 'regression'}
#
# Numerical features:
#   • train: (36212, 9)
#   • val  : (9053, 9)
#   • test : (22633, 9)
#
# Categorical features: None
#
# Targets:
#   • train: (36212,)
#   • val  : (9053,)
#   • test : (22633,)
#   Target mean (train): 0.679 | (test): 0.678
#
# 📂 Fold 3:
# Info:
# {'n_cat_features': 0, 'n_num_features': 9, 'task_type': 'regression'}
#
# Numerical features:
#   • train: (36212, 9)
#   • val  : (9054, 9)
#   • test : (22632, 9)
#
# Categorical features: None
#
# Targets:
#   • train: (36212,)
#   • val  : (9054,)
#   • test : (22632,)
#   Target mean (train): 0.678 | (test): 0.680
#
# ✅ Fold inspection complete.
#
#
# 🎯 Summary of DataFeeder Tests:
# - ✅ DataFeeder successfully loaded and preprocessed all datasets.
# - ✅ Output structure is fully TALENT-compatible (dicts with train/val/test).
# - ✅ Single-split and CV modes both operational.
# - ✅ Feature and target shapes verified per split.
# - ✅ Target distributions printed for sanity checking.
#
# 🎉 All DataFeeder tests completed successfully within notebook.
