# %%
# ================================================================
# TALENT PROCESSED DATA EXPLORATION NOTEBOOK
# ================================================================
# This notebook:
#   • Automatically finds all processed datasets in data/processed/{pd, lgd}
#   • Uses ProcessedDataInspector to run TALENT compatibility checks
#   • Pretty-prints detailed reports per dataset
#   • Produces a final summary table
# ================================================================

# ---------------------------------------------------------------
# 1️⃣ Setup imports and paths
# ---------------------------------------------------------------
import sys
from pathlib import Path
import pandas as pd

# Determine repo root (one level up from notebooks/)
repo_root = Path().resolve().parents[0] if "notebooks" in str(Path().resolve()) else Path().resolve()
src_path = repo_root / "src"
if str(repo_root) not in sys.path:
    sys.path.insert(0, str(repo_root))
if str(src_path) not in sys.path:
    sys.path.insert(0, str(src_path))

print("✅ Import paths added:")
for p in [repo_root, src_path]:
    print(f" - {p}")

# Import our inspector
from src.data.processed_data_exploration import ProcessedDataInspector


# ---------------------------------------------------------------
# 2️⃣ Discover all processed datasets
# ---------------------------------------------------------------
processed_root = repo_root / "data" / "processed"
print(f"\n📁 Using processed data root: {processed_root}")

tasks = ["pd", "lgd"]
datasets = {
    t: sorted([d.name for d in (processed_root / t).iterdir() if d.is_dir()])
    for t in tasks if (processed_root / t).exists()
}

print("\n📦 Discovered processed datasets:")
for t, names in datasets.items():
    print(f"  {t.upper()}: {len(names)} datasets found → {names}")


# ---------------------------------------------------------------
# 3️⃣ Inspect each processed dataset
# ---------------------------------------------------------------
reports = []

for task, ds_list in datasets.items():
    for ds_name in ds_list:
        print("\n" + "=" * 70)
        print(f"🔍 Inspecting processed dataset: {ds_name} [{task.upper()}]")
        print("=" * 70)
        try:
            inspector = ProcessedDataInspector(ds_name, task, processed_root=processed_root)
            report = inspector.pretty_print()
            reports.append(report)
        except Exception as e:
            print(f"❌ Failed to inspect {ds_name}: {e}")

print("\n✅ All processed datasets checked.")


# ---------------------------------------------------------------
# 4️⃣ Build summary DataFrame
# ---------------------------------------------------------------
if reports:
    df_summary = pd.DataFrame(reports)
    df_summary = df_summary[
        ["dataset", "task", "n_samples", "n_num_features", "n_cat_features", "issues"]
    ]
    print("\n📊 TALENT processed data summary:")
    display(df_summary)
else:
    print("⚠️ No valid processed datasets found — nothing to summarize.")
# Out:
# ✅ Import paths added:
#  - /Users/anderas/Documents/PhD/Projects/1. TabPFN/TabPFNCredit
#  - /Users/anderas/Documents/PhD/Projects/1. TabPFN/TabPFNCredit/src
#
# 📁 Using processed data root: /Users/anderas/Documents/PhD/Projects/1. TabPFN/TabPFNCredit/data/processed
#
# 📦 Discovered processed datasets:
#   PD: 14 datasets found → ['0001.gmsc', '0002.taiwan_creditcard', '0003.vehicle_loan', '0004.lendingclub', '0005.Case Study', '0006.myhom', '0007.hackerearth', '0008.cobranded', '0009.german', '0010.bank_status', '0011.thomas', '0012.loan_default', '0013.home_credit', '0014.hmeq']
#   LGD: 5 datasets found → ['0001.heloc', '0002.loss2', '0003.axa', '0004.base_model', '0005.base_modelisation']
#
# ======================================================================
# 🔍 Inspecting processed dataset: 0001.gmsc [PD]
# ======================================================================
#
# 📦 Dataset: 0001.gmsc [PD]
# 📁 Path: /Users/anderas/Documents/PhD/Projects/1. TabPFN/TabPFNCredit/data/processed/pd/0001.gmsc
# 🧮 Samples: 150000 | Num features: 10 | Cat features: 0
# ⚠️ Issues:
#    - ✅ All TALENT compatibility checks passed.
# ----------------------------------------------------------------------
#
# ======================================================================
# 🔍 Inspecting processed dataset: 0002.taiwan_creditcard [PD]
# ======================================================================
#
# 📦 Dataset: 0002.taiwan_creditcard [PD]
# 📁 Path: /Users/anderas/Documents/PhD/Projects/1. TabPFN/TabPFNCredit/data/processed/pd/0002.taiwan_creditcard
# 🧮 Samples: 30000 | Num features: 23 | Cat features: 0
# ⚠️ Issues:
#    - ✅ All TALENT compatibility checks passed.
# ----------------------------------------------------------------------
#
# ======================================================================
# 🔍 Inspecting processed dataset: 0003.vehicle_loan [PD]
# ======================================================================
#
# 📦 Dataset: 0003.vehicle_loan [PD]
# 📁 Path: /Users/anderas/Documents/PhD/Projects/1. TabPFN/TabPFNCredit/data/processed/pd/0003.vehicle_loan
# 🧮 Samples: 233154 | Num features: 32 | Cat features: 3
# ⚠️ Issues:
#    - C contains 7661 entries with -1 (missing category placeholders).
#    - 2 constant columns in N (first few indices: [26, 27])
# ----------------------------------------------------------------------
#
# ======================================================================
# 🔍 Inspecting processed dataset: 0004.lendingclub [PD]
# ======================================================================
#
# 📦 Dataset: 0004.lendingclub [PD]
# 📁 Path: /Users/anderas/Documents/PhD/Projects/1. TabPFN/TabPFNCredit/data/processed/pd/0004.lendingclub
# 🧮 Samples: 9578 | Num features: 12 | Cat features: 1
# ⚠️ Issues:
#    - ✅ All TALENT compatibility checks passed.
# ----------------------------------------------------------------------
#
# ======================================================================
# 🔍 Inspecting processed dataset: 0005.Case Study [PD]
# ======================================================================
#
# 📦 Dataset: 0005.Case Study [PD]
# 📁 Path: /Users/anderas/Documents/PhD/Projects/1. TabPFN/TabPFNCredit/data/processed/pd/0005.Case Study
# 🧮 Samples: 150000 | Num features: 10 | Cat features: 1
# ⚠️ Issues:
#    - C contains 82 entries with -1 (missing category placeholders).
# ----------------------------------------------------------------------
#
# ======================================================================
# 🔍 Inspecting processed dataset: 0006.myhom [PD]
# ======================================================================
#
# 📦 Dataset: 0006.myhom [PD]
# 📁 Path: /Users/anderas/Documents/PhD/Projects/1. TabPFN/TabPFNCredit/data/processed/pd/0006.myhom
# 🧮 Samples: 7000 | Num features: 7 | Cat features: 1
# ⚠️ Issues:
#    - ✅ All TALENT compatibility checks passed.
# ----------------------------------------------------------------------
#
# ======================================================================
# 🔍 Inspecting processed dataset: 0007.hackerearth [PD]
# ======================================================================
#
# 📦 Dataset: 0007.hackerearth [PD]
# 📁 Path: /Users/anderas/Documents/PhD/Projects/1. TabPFN/TabPFNCredit/data/processed/pd/0007.hackerearth
# 🧮 Samples: 532428 | Num features: 35 | Cat features: 8
# ⚠️ Issues:
#    - ✅ All TALENT compatibility checks passed.
# ----------------------------------------------------------------------
#
# ======================================================================
# 🔍 Inspecting processed dataset: 0008.cobranded [PD]
# ======================================================================
#
# 📦 Dataset: 0008.cobranded [PD]
# 📁 Path: /Users/anderas/Documents/PhD/Projects/1. TabPFN/TabPFNCredit/data/processed/pd/0008.cobranded
# 🧮 Samples: 80000 | Num features: 47 | Cat features: 0
# ⚠️ Issues:
#    - ✅ All TALENT compatibility checks passed.
# ----------------------------------------------------------------------
#
# ======================================================================
# 🔍 Inspecting processed dataset: 0009.german [PD]
# ======================================================================
#
# 📦 Dataset: 0009.german [PD]
# 📁 Path: /Users/anderas/Documents/PhD/Projects/1. TabPFN/TabPFNCredit/data/processed/pd/0009.german
# 🧮 Samples: 999 | Num features: 7 | Cat features: 13
# ⚠️ Issues:
#    - ✅ All TALENT compatibility checks passed.
# ----------------------------------------------------------------------
#
# ======================================================================
# 🔍 Inspecting processed dataset: 0010.bank_status [PD]
# ======================================================================
#
# 📦 Dataset: 0010.bank_status [PD]
# 📁 Path: /Users/anderas/Documents/PhD/Projects/1. TabPFN/TabPFNCredit/data/processed/pd/0010.bank_status
# 🧮 Samples: 100000 | Num features: 16 | Cat features: 0
# ⚠️ Issues:
#    - ✅ All TALENT compatibility checks passed.
# ----------------------------------------------------------------------
#
# ======================================================================
# 🔍 Inspecting processed dataset: 0011.thomas [PD]
# ======================================================================
#
# 📦 Dataset: 0011.thomas [PD]
# 📁 Path: /Users/anderas/Documents/PhD/Projects/1. TabPFN/TabPFNCredit/data/processed/pd/0011.thomas
# 🧮 Samples: 1225 | Num features: 12 | Cat features: 2
# ⚠️ Issues:
#    - ✅ All TALENT compatibility checks passed.
# ----------------------------------------------------------------------
#
# ======================================================================
# 🔍 Inspecting processed dataset: 0012.loan_default [PD]
# ======================================================================
# /Users/anderas/Documents/PhD/Projects/1. TabPFN/TabPFNCredit/.venv/lib/python3.9/site-packages/numpy/core/fromnumeric.py:88: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# /Users/anderas/Documents/PhD/Projects/1. TabPFN/TabPFNCredit/.venv/lib/python3.9/site-packages/numpy/lib/nanfunctions.py:1741: RuntimeWarning: invalid value encountered in subtract
#   np.subtract(arr, avg, out=arr, casting='unsafe', where=where)
# /Users/anderas/Documents/PhD/Projects/1. TabPFN/TabPFNCredit/.venv/lib/python3.9/site-packages/numpy/lib/nanfunctions.py:1746: RuntimeWarning: overflow encountered in multiply
#   sqr = np.multiply(arr, arr, out=arr, where=where)
# 📦 Dataset: 0012.loan_default [PD]
# 📁 Path: /Users/anderas/Documents/PhD/Projects/1. TabPFN/TabPFNCredit/data/processed/pd/0012.loan_default
# 🧮 Samples: 105471 | Num features: 759 | Cat features: 0
# ⚠️ Issues:
#    - N contains infinite values (e.g., at indices [[4, 383], [4, 612], [5, 383], [5, 612], [6, 383]])
#    - 1 constant columns in N (first few indices: [663])
# ----------------------------------------------------------------------
#
# ======================================================================
# 🔍 Inspecting processed dataset: 0013.home_credit [PD]
# ======================================================================
#
# 📦 Dataset: 0013.home_credit [PD]
# 📁 Path: /Users/anderas/Documents/PhD/Projects/1. TabPFN/TabPFNCredit/data/processed/pd/0013.home_credit
# 🧮 Samples: 307511 | Num features: 104 | Cat features: 16
# ⚠️ Issues:
#    - C contains 764371 entries with -1 (missing category placeholders).
# ----------------------------------------------------------------------
#
# ======================================================================
# 🔍 Inspecting processed dataset: 0014.hmeq [PD]
# ======================================================================
#
# 📦 Dataset: 0014.hmeq [PD]
# 📁 Path: /Users/anderas/Documents/PhD/Projects/1. TabPFN/TabPFNCredit/data/processed/pd/0014.hmeq
# 🧮 Samples: 5960 | Num features: 10 | Cat features: 2
# ⚠️ Issues:
#    - C contains 531 entries with -1 (missing category placeholders).
# ----------------------------------------------------------------------
#
# ======================================================================
# 🔍 Inspecting processed dataset: 0001.heloc [LGD]
# ======================================================================
#
# 📦 Dataset: 0001.heloc [LGD]
# 📁 Path: /Users/anderas/Documents/PhD/Projects/1. TabPFN/TabPFNCredit/data/processed/lgd/0001.heloc
# 🧮 Samples: 67898 | Num features: 9 | Cat features: 0
# ⚠️ Issues:
#    - ✅ All TALENT compatibility checks passed.
# ----------------------------------------------------------------------
#
# ======================================================================
# 🔍 Inspecting processed dataset: 0002.loss2 [LGD]
# ======================================================================
#
# 📦 Dataset: 0002.loss2 [LGD]
# 📁 Path: /Users/anderas/Documents/PhD/Projects/1. TabPFN/TabPFNCredit/data/processed/lgd/0002.loss2
# 🧮 Samples: 4638 | Num features: 39 | Cat features: 23
# ⚠️ Issues:
#    - C contains 5789 entries with -1 (missing category placeholders).
# ----------------------------------------------------------------------
#
# ======================================================================
# 🔍 Inspecting processed dataset: 0003.axa [LGD]
# ======================================================================
#
# 📦 Dataset: 0003.axa [LGD]
# 📁 Path: /Users/anderas/Documents/PhD/Projects/1. TabPFN/TabPFNCredit/data/processed/lgd/0003.axa
# 🧮 Samples: 2545 | Num features: 2 | Cat features: 0
# ⚠️ Issues:
#    - ✅ All TALENT compatibility checks passed.
# ----------------------------------------------------------------------
#
# ======================================================================
# 🔍 Inspecting processed dataset: 0004.base_model [LGD]
# ======================================================================
#
# 📦 Dataset: 0004.base_model [LGD]
# 📁 Path: /Users/anderas/Documents/PhD/Projects/1. TabPFN/TabPFNCredit/data/processed/lgd/0004.base_model
# 🧮 Samples: 762 | Num features: 114 | Cat features: 88
# ⚠️ Issues:
#    - C contains 11486 entries with -1 (missing category placeholders).
#    - 5 constant columns in N (first few indices: [1, 2, 20, 21, 37])
#    - 1 constant columns in C (first few indices: [45])
# ----------------------------------------------------------------------
#
# ======================================================================
# 🔍 Inspecting processed dataset: 0005.base_modelisation [LGD]
# ======================================================================
#
# 📦 Dataset: 0005.base_modelisation [LGD]
# 📁 Path: /Users/anderas/Documents/PhD/Projects/1. TabPFN/TabPFNCredit/data/processed/lgd/0005.base_modelisation
# 🧮 Samples: 594 | Num features: 179 | Cat features: 77
# ⚠️ Issues:
#    - C contains 151 entries with -1 (missing category placeholders).
#    - 4 constant columns in C (first few indices: [5, 6, 10, 21])
# ----------------------------------------------------------------------
#
# ✅ All processed datasets checked.
#
# 📊 TALENT processed data summary:
#                    dataset task  n_samples  n_num_features  n_cat_features  \
# 0                0001.gmsc   pd     150000              10               0
# 1   0002.taiwan_creditcard   pd      30000              23               0
# 2        0003.vehicle_loan   pd     233154              32               3
# 3         0004.lendingclub   pd       9578              12               1
# 4          0005.Case Study   pd     150000              10               1
# 5               0006.myhom   pd       7000               7               1
# 6         0007.hackerearth   pd     532428              35               8
# 7           0008.cobranded   pd      80000              47               0
# 8              0009.german   pd        999               7              13
# 9         0010.bank_status   pd     100000              16               0
# 10             0011.thomas   pd       1225              12               2
# 11       0012.loan_default   pd     105471             759               0
# 12        0013.home_credit   pd     307511             104              16
# 13               0014.hmeq   pd       5960              10               2
# 14              0001.heloc  lgd      67898               9               0
# 15              0002.loss2  lgd       4638              39              23
# 16                0003.axa  lgd       2545               2               0
# 17         0004.base_model  lgd        762             114              88
# 18  0005.base_modelisation  lgd        594             179              77
#
#                                                issues
# 0         [✅ All TALENT compatibility checks passed.]
# 1         [✅ All TALENT compatibility checks passed.]
# 2   [C contains 7661 entries with -1 (missing cate...
# 3         [✅ All TALENT compatibility checks passed.]
# 4   [C contains 82 entries with -1 (missing catego...
# 5         [✅ All TALENT compatibility checks passed.]
# 6         [✅ All TALENT compatibility checks passed.]
# 7         [✅ All TALENT compatibility checks passed.]
# 8         [✅ All TALENT compatibility checks passed.]
# 9         [✅ All TALENT compatibility checks passed.]
# 10        [✅ All TALENT compatibility checks passed.]
# 11  [N contains infinite values (e.g., at indices ...
# 12  [C contains 764371 entries with -1 (missing ca...
# 13  [C contains 531 entries with -1 (missing categ...
# 14        [✅ All TALENT compatibility checks passed.]
# 15  [C contains 5789 entries with -1 (missing cate...
# 16        [✅ All TALENT compatibility checks passed.]
# 17  [C contains 11486 entries with -1 (missing cat...
# 18  [C contains 151 entries with -1 (missing categ...
