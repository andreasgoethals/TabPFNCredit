# %%
# Notebook: Run Experiment 1
# This notebook runs the complete HPO benchmark experiment

import sys
from pathlib import Path

# Setup path - notebook is in notebooks/, project root is one level up
PROJECT_ROOT = Path.cwd().parent
sys.path.insert(0, str(PROJECT_ROOT))

# Import and run experiment
from scripts.Experiment1 import run_experiment1

run_experiment1(
    experiment_name="experiment1",
    skip_completed=True,  # Set to False to re-run all datasets
    verbose=True
)
# Out:
# 2025-11-17 11:53:29,617 - scripts.Experiment1 - INFO - ================================================================================
# 2025-11-17 11:53:29,617 - scripts.Experiment1 - INFO - EXPERIMENT 1: HPO Benchmark
# 2025-11-17 11:53:29,617 - scripts.Experiment1 - INFO - ================================================================================
# 2025-11-17 11:53:29,617 - scripts.Experiment1 - INFO - Loading configuration...
# 2025-11-17 11:53:29,659 - scripts.Experiment1 - INFO - Results will be saved to: C:\Users\U0152019\OneDrive - KU Leuven\PhD Documents\Projects\1. TabPFN\TabPFNCredit\results\experiment1
# 2025-11-17 11:53:29,660 - scripts.Experiment1 - INFO - Log file: C:\Users\U0152019\OneDrive - KU Leuven\PhD Documents\Projects\1. TabPFN\TabPFNCredit\results\experiment1\experiment1.log
# 2025-11-17 11:53:29,660 - scripts.Experiment1 - INFO - HPO configs will be saved to: C:\Users\U0152019\OneDrive - KU Leuven\PhD Documents\Projects\1. TabPFN\TabPFNCredit\results\experiment1\config_hpo
# 2025-11-17 11:53:29,662 - src.utils.storage_handler - INFO - Saved experiment metadata to C:\Users\U0152019\OneDrive - KU Leuven\PhD Documents\Projects\1. TabPFN\TabPFNCredit\results\experiment1\experiment_metadata.json
# 2025-11-17 11:53:29,662 - scripts.Experiment1 - INFO - Found 1 PD datasets and 1 LGD datasets
# 2025-11-17 11:53:29,663 - scripts.Experiment1 - INFO - Total datasets to process: 2
# 2025-11-17 11:53:29,663 - scripts.Experiment1 - INFO -
# ================================================================================
# 2025-11-17 11:53:29,663 - scripts.Experiment1 - INFO - Dataset 1/2: 0001.gmsc (PD)
# 2025-11-17 11:53:29,665 - scripts.Experiment1 - INFO - ================================================================================
# 2025-11-17 11:53:29,665 - scripts.Experiment1 - INFO - Running HPO comparison...
# 2025-11-17 11:53:29,666 - src.methods.HPO_runner - INFO - Starting HPO comparison for 0001.gmsc
# 2025-11-17 11:53:29,675 - src.methods.all_methods_runner - INFO - Running all methods on 0001.gmsc (14 methods)
# 2025-11-17 11:53:29,676 - src.methods.method_runner - INFO - Starting catboost on 0001.gmsc
# 2025-11-17 11:53:29,677 - src.data.data_feeder - INFO - Preparing data: 0001.gmsc (PD)
# 2025-11-17 11:53:29,678 - src.data.preprocessing - INFO -  Using cached dataset: C:\Users\U0152019\OneDrive - KU Leuven\PhD Documents\Projects\1. TabPFN\TabPFNCredit\data\processed\pd\0001.gmsc
# 2025-11-17 11:53:29,716 - src.data.data_feeder - INFO - Data prepared: 0001.gmsc
# Found existing experiment folder: C:\Users\U0152019\OneDrive - KU Leuven\PhD Documents\Projects\1. TabPFN\TabPFNCredit\results\experiment1
# Archiving old results before starting new run...
# ✓ Archived to: C:\Users\U0152019\OneDrive - KU Leuven\PhD Documents\Projects\1. TabPFN\TabPFNCredit\results\archive\20251117_115329_experiment1
#
#
# ================================================================================
# Running HPO comparison for dataset: 0001.gmsc (PD)
# ================================================================================
#
# [PHASE 1/2] Running all methods with default configurations...
#
# ======================================================================
# Running catboost (classical) on 0001.gmsc (PD)
# ======================================================================
#
# Preparing data with 5 CV splits...
# Fold IDs: [1, 2, 3, 4, 5]
# First fold ID: 1
#
# Directory setup:
#   Config directory (persistent): C:\Users\U0152019\OneDrive - KU Leuven\PhD Documents\Projects\1. TabPFN\TabPFNCredit\results\experiment1\config_hpo\pd\0001.gmsc
#   Checkpoint directory (temp):   C:\Users\U0152019\AppData\Local\Temp\talent_ckpt_0001.gmsc_catboost_9_knlzxt
#
# [HPO] Mode: DISABLED
# [HPO] All folds: Will use TALENT's default hyperparameters
#
# ======================================================================
# Fold 1/5
# ======================================================================
# using gpu: 0
# {'cat_min_frequency': 0.0,
#  'cat_nan_policy': 'new',
#  'cat_policy': 'ordinal',
#  'config': {'fit': {'logging_level': 'Silent'},
#             'model': {'early_stopping_rounds': 50,
#                       'n_estimators': 2000,
#                       'od_pval': 0.001}},
#  'dataset': '0001.gmsc',
#  'dataset_path': './data',
#  'evaluate_option': 'best-val',
#  'gpu': '0',
#  'model_path': 'C:\\Users\\U0152019\\AppData\\Local\\Temp\\talent_ckpt_0001.gmsc_catboost_9_knlzxt',
#  'model_type': 'catboost',
#  'n_bins': 2,
#  'n_trials': 100,
#  'normalization': 'standard',
#  'num_nan_policy': 'mean',
#  'num_policy': 'none',
#  'retune': False,
#  'save_path': 'C:\\Users\\U0152019\\AppData\\Local\\Temp\\talent_ckpt_0001.gmsc_catboost_9_knlzxt\\0001.gmsc-catboost\\Norm-standard-Nan-mean-new-Cat-ordinal',
#  'seed': 0,
#  'seed_num': 15,
#  'tune': False}
#
# Preprocessing configuration:
#   - cat_policy: indices
#   - num_policy: none
#   - normalization: standard
#   - num_nan_policy: mean
#   - cat_nan_policy: new
#
# [DEFAULT] Using TALENT's default hyperparameters
# [DEFAULT] Location: .venv/.../TALENT/configs/default/catboost.json
# [DEFAULT] Saved configs in config_hpo/ are ignored when tune=False
# {'fit': {'logging_level': 'Silent', 'n_bins': 2}, 'model': {'early_stopping_rounds': 50, 'n_estimators': 2000, 'od_pval': 0.001}}
#
# Fold 1 results:
#   Accuracy: 0.9550
#   Avg_Recall: 0.6250
#   Avg_Precision: 0.9772
#   F1: 0.4000
#   LogLoss: 0.1428
#   AUC: 0.8839
#
# ======================================================================
# Fold 2/5
# ======================================================================
# using gpu: 0
# {'cat_min_frequency': 0.0,
#  'cat_nan_policy': 'new',
#  'cat_policy': 'ordinal',
#  'config': {'fit': {'logging_level': 'Silent'},
#             'model': {'early_stopping_rounds': 50,
#                       'n_estimators': 2000,
#                       'od_pval': 0.001}},
#  'dataset': '0001.gmsc',
#  'dataset_path': './data',
#  'evaluate_option': 'best-val',
#  'gpu': '0',
#  'model_path': 'C:\\Users\\U0152019\\AppData\\Local\\Temp\\talent_ckpt_0001.gmsc_catboost_9_knlzxt',
#  'model_type': 'catboost',
#  'n_bins': 2,
#  'n_trials': 100,
#  'normalization': 'standard',
#  'num_nan_policy': 'mean',
#  'num_policy': 'none',
#  'retune': False,
#  'save_path': 'C:\\Users\\U0152019\\AppData\\Local\\Temp\\talent_ckpt_0001.gmsc_catboost_9_knlzxt\\0001.gmsc-catboost\\Norm-standard-Nan-mean-new-Cat-ordinal',
#  'seed': 0,
#  'seed_num': 15,
#  'tune': False}
# {'fit': {'logging_level': 'Silent', 'n_bins': 2}, 'model': {'early_stopping_rounds': 50, 'n_estimators': 2000, 'od_pval': 0.001}}
#
# Fold 2 results:
#   Accuracy: 0.9350
#   Avg_Recall: 0.4973
#   Avg_Precision: 0.4698
#   F1: 0.0000
#   LogLoss: 0.1942
#   AUC: 0.7921
#
# ======================================================================
# Fold 3/5
# ======================================================================
# using gpu: 0
# {'cat_min_frequency': 0.0,
#  'cat_nan_policy': 'new',
#  'cat_policy': 'ordinal',
#  'config': {'fit': {'logging_level': 'Silent'},
#             'model': {'early_stopping_rounds': 50,
#                       'n_estimators': 2000,
#                       'od_pval': 0.001}},
#  'dataset': '0001.gmsc',
#  'dataset_path': './data',
#  'evaluate_option': 'best-val',
#  'gpu': '0',
#  'model_path': 'C:\\Users\\U0152019\\AppData\\Local\\Temp\\talent_ckpt_0001.gmsc_catboost_9_knlzxt',
#  'model_type': 'catboost',
#  'n_bins': 2,
#  'n_trials': 100,
#  'normalization': 'standard',
#  'num_nan_policy': 'mean',
#  'num_policy': 'none',
#  'retune': False,
#  'save_path': 'C:\\Users\\U0152019\\AppData\\Local\\Temp\\talent_ckpt_0001.gmsc_catboost_9_knlzxt\\0001.gmsc-catboost\\Norm-standard-Nan-mean-new-Cat-ordinal',
#  'seed': 0,
#  'seed_num': 15,
#  'tune': False}
# {'fit': {'logging_level': 'Silent', 'n_bins': 2}, 'model': {'early_stopping_rounds': 50, 'n_estimators': 2000, 'od_pval': 0.001}}
#
# Fold 3 results:
#   Accuracy: 0.9400
#   Avg_Recall: 0.4974
#   Avg_Precision: 0.4724
#   F1: 0.0000
#   LogLoss: 0.1826
#   AUC: 0.8302
#
# ======================================================================
# Fold 4/5
# ======================================================================
# using gpu: 0
# {'cat_min_frequency': 0.0,
#  'cat_nan_policy': 'new',
#  'cat_policy': 'ordinal',
#  'config': {'fit': {'logging_level': 'Silent'},
#             'model': {'early_stopping_rounds': 50,
#                       'n_estimators': 2000,
#                       'od_pval': 0.001}},
#  'dataset': '0001.gmsc',
#  'dataset_path': './data',
#  'evaluate_option': 'best-val',
#  'gpu': '0',
#  'model_path': 'C:\\Users\\U0152019\\AppData\\Local\\Temp\\talent_ckpt_0001.gmsc_catboost_9_knlzxt',
#  'model_type': 'catboost',
#  'n_bins': 2,
#  'n_trials': 100,
#  'normalization': 'standard',
#  'num_nan_policy': 'mean',
#  'num_policy': 'none',
#  'retune': False,
#  'save_path': 'C:\\Users\\U0152019\\AppData\\Local\\Temp\\talent_ckpt_0001.gmsc_catboost_9_knlzxt\\0001.gmsc-catboost\\Norm-standard-Nan-mean-new-Cat-ordinal',
#  'seed': 0,
#  'seed_num': 15,
#  'tune': False}
# {'fit': {'logging_level': 'Silent', 'n_bins': 2}, 'model': {'early_stopping_rounds': 50, 'n_estimators': 2000, 'od_pval': 0.001}}
#
# Fold 4 results:
#   Accuracy: 0.9400
#   Avg_Recall: 0.4974
#   Avg_Precision: 0.4724
#   F1: 0.0000
#   LogLoss: 0.1877
#   AUC: 0.8196
#
# ======================================================================
# Fold 5/5
# ======================================================================
# using gpu: 0
# {'cat_min_frequency': 0.0,
#  'cat_nan_policy': 'new',
#  'cat_policy': 'ordinal',
#  'config': {'fit': {'logging_level': 'Silent'},
#             'model': {'early_stopping_rounds': 50,
#                       'n_estimators': 2000,
#                       'od_pval': 0.001}},
#  'dataset': '0001.gmsc',
#  'dataset_path': './data',
#  'evaluate_option': 'best-val',
#  'gpu': '0',
#  'model_path': 'C:\\Users\\U0152019\\AppData\\Local\\Temp\\talent_ckpt_0001.gmsc_catboost_9_knlzxt',
#  'model_type': 'catboost',
#  'n_bins': 2,
#  'n_trials': 100,
#  'normalization': 'standard',
#  'num_nan_policy': 'mean',
#  'num_policy': 'none',
#  'retune': False,
#  'save_path': 'C:\\Users\\U0152019\\AppData\\Local\\Temp\\talent_ckpt_0001.gmsc_catboost_9_knlzxt\\0001.gmsc-catboost\\Norm-standard-Nan-mean-new-Cat-ordinal',
#  'seed': 0,
#  'seed_num': 15,
#  'tune': False}
# {'fit': {'logging_level': 'Silent', 'n_bins': 2}, 'model': {'early_stopping_rounds': 50, 'n_estimators': 2000, 'od_pval': 0.001}}
# 2025-11-17 11:53:39,342 - src.methods.method_runner - INFO - Finished catboost on 0001.gmsc
# 2025-11-17 11:53:39,342 - src.methods.method_runner - INFO - Starting knn on 0001.gmsc
# 2025-11-17 11:53:39,342 - src.data.data_feeder - INFO - Preparing data: 0001.gmsc (PD)
# 2025-11-17 11:53:39,342 - src.data.preprocessing - INFO -  Using cached dataset: C:\Users\U0152019\OneDrive - KU Leuven\PhD Documents\Projects\1. TabPFN\TabPFNCredit\data\processed\pd\0001.gmsc
# 2025-11-17 11:53:39,352 - src.data.data_feeder - INFO - Data prepared: 0001.gmsc
# 2025-11-17 11:53:39,478 - src.methods.method_runner - INFO - Finished knn on 0001.gmsc
# 2025-11-17 11:53:39,479 - src.methods.method_runner - INFO - Starting lightgbm on 0001.gmsc
# 2025-11-17 11:53:39,479 - src.data.data_feeder - INFO - Preparing data: 0001.gmsc (PD)
# 2025-11-17 11:53:39,480 - src.data.preprocessing - INFO -  Using cached dataset: C:\Users\U0152019\OneDrive - KU Leuven\PhD Documents\Projects\1. TabPFN\TabPFNCredit\data\processed\pd\0001.gmsc
# 2025-11-17 11:53:39,486 - src.data.data_feeder - INFO - Data prepared: 0001.gmsc
# Fold 5 results:
#   Accuracy: 0.9450
#   Avg_Recall: 0.5000
#   Avg_Precision: 0.4725
#   F1: 0.0000
#   LogLoss: 0.1717
#   AUC: 0.8331
#
# ======================================================================
# Completed 5 folds for catboost
# ======================================================================
#
#
# ======================================================================
# Running knn (classical) on 0001.gmsc (PD)
# ======================================================================
#
# Preparing data with 5 CV splits...
# Fold IDs: [1, 2, 3, 4, 5]
# First fold ID: 1
#
# Directory setup:
#   Config directory (persistent): C:\Users\U0152019\OneDrive - KU Leuven\PhD Documents\Projects\1. TabPFN\TabPFNCredit\results\experiment1\config_hpo\pd\0001.gmsc
#   Checkpoint directory (temp):   C:\Users\U0152019\AppData\Local\Temp\talent_ckpt_0001.gmsc_knn_tpr0ospp
#
# [HPO] Mode: DISABLED
# [HPO] All folds: Will use TALENT's default hyperparameters
#
# ======================================================================
# Fold 1/5
# ======================================================================
# using gpu: 0
# {'cat_min_frequency': 0.0,
#  'cat_nan_policy': 'new',
#  'cat_policy': 'ordinal',
#  'config': {'fit': {},
#             'model': {'algorithm': 'auto',
#                       'metric': 'minkowski',
#                       'p': 2,
#                       'weights': 'distance'}},
#  'dataset': '0001.gmsc',
#  'dataset_path': './data',
#  'evaluate_option': 'best-val',
#  'gpu': '0',
#  'model_path': 'C:\\Users\\U0152019\\AppData\\Local\\Temp\\talent_ckpt_0001.gmsc_knn_tpr0ospp',
#  'model_type': 'knn',
#  'n_bins': 2,
#  'n_trials': 100,
#  'normalization': 'standard',
#  'num_nan_policy': 'mean',
#  'num_policy': 'none',
#  'retune': False,
#  'save_path': 'C:\\Users\\U0152019\\AppData\\Local\\Temp\\talent_ckpt_0001.gmsc_knn_tpr0ospp\\0001.gmsc-knn\\Norm-standard-Nan-mean-new-Cat-ordinal',
#  'seed': 0,
#  'seed_num': 15,
#  'tune': False}
#
# Preprocessing configuration:
#   - cat_policy: ordinal
#   - num_policy: none
#   - normalization: standard
#   - num_nan_policy: mean
#   - cat_nan_policy: new
#
# [DEFAULT] Using TALENT's default hyperparameters
# [DEFAULT] Location: .venv/.../TALENT/configs/default/knn.json
# [DEFAULT] Saved configs in config_hpo/ are ignored when tune=False
# {'model': {'weights': 'distance', 'algorithm': 'auto', 'p': 2, 'metric': 'minkowski'}, 'fit': {'n_bins': 2}}
#
# Fold 1 results:
#   Accuracy: 0.9300
#   Avg_Recall: 0.4947
#   Avg_Precision: 0.4697
#   F1: 0.0000
#   LogLoss: 1.0036
#   AUC: 0.7010
#
# ======================================================================
# Fold 2/5
# ======================================================================
# using gpu: 0
# {'cat_min_frequency': 0.0,
#  'cat_nan_policy': 'new',
#  'cat_policy': 'ordinal',
#  'config': {'fit': {},
#             'model': {'algorithm': 'auto',
#                       'metric': 'minkowski',
#                       'p': 2,
#                       'weights': 'distance'}},
#  'dataset': '0001.gmsc',
#  'dataset_path': './data',
#  'evaluate_option': 'best-val',
#  'gpu': '0',
#  'model_path': 'C:\\Users\\U0152019\\AppData\\Local\\Temp\\talent_ckpt_0001.gmsc_knn_tpr0ospp',
#  'model_type': 'knn',
#  'n_bins': 2,
#  'n_trials': 100,
#  'normalization': 'standard',
#  'num_nan_policy': 'mean',
#  'num_policy': 'none',
#  'retune': False,
#  'save_path': 'C:\\Users\\U0152019\\AppData\\Local\\Temp\\talent_ckpt_0001.gmsc_knn_tpr0ospp\\0001.gmsc-knn\\Norm-standard-Nan-mean-new-Cat-ordinal',
#  'seed': 0,
#  'seed_num': 15,
#  'tune': False}
# {'model': {'weights': 'distance', 'algorithm': 'auto', 'p': 2, 'metric': 'minkowski'}, 'fit': {'n_bins': 2}}
#
# Fold 2 results:
#   Accuracy: 0.9300
#   Avg_Recall: 0.4947
#   Avg_Precision: 0.4697
#   F1: 0.0000
#   LogLoss: 1.1908
#   AUC: 0.6334
#
# ======================================================================
# Fold 3/5
# ======================================================================
# using gpu: 0
# {'cat_min_frequency': 0.0,
#  'cat_nan_policy': 'new',
#  'cat_policy': 'ordinal',
#  'config': {'fit': {},
#             'model': {'algorithm': 'auto',
#                       'metric': 'minkowski',
#                       'p': 2,
#                       'weights': 'distance'}},
#  'dataset': '0001.gmsc',
#  'dataset_path': './data',
#  'evaluate_option': 'best-val',
#  'gpu': '0',
#  'model_path': 'C:\\Users\\U0152019\\AppData\\Local\\Temp\\talent_ckpt_0001.gmsc_knn_tpr0ospp',
#  'model_type': 'knn',
#  'n_bins': 2,
#  'n_trials': 100,
#  'normalization': 'standard',
#  'num_nan_policy': 'mean',
#  'num_policy': 'none',
#  'retune': False,
#  'save_path': 'C:\\Users\\U0152019\\AppData\\Local\\Temp\\talent_ckpt_0001.gmsc_knn_tpr0ospp\\0001.gmsc-knn\\Norm-standard-Nan-mean-new-Cat-ordinal',
#  'seed': 0,
#  'seed_num': 15,
#  'tune': False}
# {'model': {'weights': 'distance', 'algorithm': 'auto', 'p': 2, 'metric': 'minkowski'}, 'fit': {'n_bins': 2}}
#
# Fold 3 results:
#   Accuracy: 0.9400
#   Avg_Recall: 0.5830
#   Avg_Precision: 0.6769
#   F1: 0.2500
#   LogLoss: 1.3437
#   AUC: 0.5967
#
# ======================================================================
# Fold 4/5
# ======================================================================
# using gpu: 0
# {'cat_min_frequency': 0.0,
#  'cat_nan_policy': 'new',
#  'cat_policy': 'ordinal',
#  'config': {'fit': {},
#             'model': {'algorithm': 'auto',
#                       'metric': 'minkowski',
#                       'p': 2,
#                       'weights': 'distance'}},
#  'dataset': '0001.gmsc',
#  'dataset_path': './data',
#  'evaluate_option': 'best-val',
#  'gpu': '0',
#  'model_path': 'C:\\Users\\U0152019\\AppData\\Local\\Temp\\talent_ckpt_0001.gmsc_knn_tpr0ospp',
#  'model_type': 'knn',
#  'n_bins': 2,
#  'n_trials': 100,
#  'normalization': 'standard',
#  'num_nan_policy': 'mean',
#  'num_policy': 'none',
#  'retune': False,
#  'save_path': 'C:\\Users\\U0152019\\AppData\\Local\\Temp\\talent_ckpt_0001.gmsc_knn_tpr0ospp\\0001.gmsc-knn\\Norm-standard-Nan-mean-new-Cat-ordinal',
#  'seed': 0,
#  'seed_num': 15,
#  'tune': False}
# {'model': {'weights': 'distance', 'algorithm': 'auto', 'p': 2, 'metric': 'minkowski'}, 'fit': {'n_bins': 2}}
#
# Fold 4 results:
#   Accuracy: 0.9200
#   Avg_Recall: 0.4868
#   Avg_Precision: 0.4718
#   F1: 0.0000
#   LogLoss: 1.5263
#   AUC: 0.5613
#
# ======================================================================
# Fold 5/5
# ======================================================================
# using gpu: 0
# {'cat_min_frequency': 0.0,
#  'cat_nan_policy': 'new',
#  'cat_policy': 'ordinal',
#  'config': {'fit': {},
#             'model': {'algorithm': 'auto',
#                       'metric': 'minkowski',
#                       'p': 2,
#                       'weights': 'distance'}},
#  'dataset': '0001.gmsc',
#  'dataset_path': './data',
#  'evaluate_option': 'best-val',
#  'gpu': '0',
#  'model_path': 'C:\\Users\\U0152019\\AppData\\Local\\Temp\\talent_ckpt_0001.gmsc_knn_tpr0ospp',
#  'model_type': 'knn',
#  'n_bins': 2,
#  'n_trials': 100,
#  'normalization': 'standard',
#  'num_nan_policy': 'mean',
#  'num_policy': 'none',
#  'retune': False,
#  'save_path': 'C:\\Users\\U0152019\\AppData\\Local\\Temp\\talent_ckpt_0001.gmsc_knn_tpr0ospp\\0001.gmsc-knn\\Norm-standard-Nan-mean-new-Cat-ordinal',
#  'seed': 0,
#  'seed_num': 15,
#  'tune': False}
# {'model': {'weights': 'distance', 'algorithm': 'auto', 'p': 2, 'metric': 'minkowski'}, 'fit': {'n_bins': 2}}
#
# Fold 5 results:
#   Accuracy: 0.9400
#   Avg_Recall: 0.4974
#   Avg_Precision: 0.4724
#   F1: 0.0000
#   LogLoss: 1.0035
#   AUC: 0.6780
#
# ======================================================================
# Completed 5 folds for knn
# ======================================================================
#
#
# ======================================================================
# Running lightgbm (classical) on 0001.gmsc (PD)
# ======================================================================
#
# Preparing data with 5 CV splits...
# Fold IDs: [1, 2, 3, 4, 5]
# First fold ID: 1
#
# Directory setup:
#   Config directory (persistent): C:\Users\U0152019\OneDrive - KU Leuven\PhD Documents\Projects\1. TabPFN\TabPFNCredit\results\experiment1\config_hpo\pd\0001.gmsc
#   Checkpoint directory (temp):   C:\Users\U0152019\AppData\Local\Temp\talent_ckpt_0001.gmsc_lightgbm_sz8anumm
#
# [HPO] Mode: DISABLED
# [HPO] All folds: Will use TALENT's default hyperparameters
#
# ======================================================================
# Fold 1/5
# ======================================================================
# using gpu: 0
# {'cat_min_frequency': 0.0,
#  'cat_nan_policy': 'new',
#  'cat_policy': 'ordinal',
#  'config': {'fit': {}, 'model': {'n_estimators': 2000}},
#  'dataset': '0001.gmsc',
#  'dataset_path': './data',
#  'evaluate_option': 'best-val',
#  'gpu': '0',
#  'model_path': 'C:\\Users\\U0152019\\AppData\\Local\\Temp\\talent_ckpt_0001.gmsc_lightgbm_sz8anumm',
#  'model_type': 'lightgbm',
#  'n_bins': 2,
#  'n_trials': 100,
#  'normalization': 'standard',
#  'num_nan_policy': 'mean',
#  'num_policy': 'none',
#  'retune': False,
#  'save_path': 'C:\\Users\\U0152019\\AppData\\Local\\Temp\\talent_ckpt_0001.gmsc_lightgbm_sz8anumm\\0001.gmsc-lightgbm\\Norm-standard-Nan-mean-new-Cat-ordinal',
#  'seed': 0,
#  'seed_num': 15,
#  'tune': False}
#
# Preprocessing configuration:
#   - cat_policy: ordinal
#   - num_policy: none
#   - normalization: standard
#   - num_nan_policy: mean
#   - cat_nan_policy: new
#
# [DEFAULT] Using TALENT's default hyperparameters
# [DEFAULT] Location: .venv/.../TALENT/configs/default/lightgbm.json
# [DEFAULT] Saved configs in config_hpo/ are ignored when tune=False
# {'model': {'n_estimators': 2000}, 'fit': {'n_bins': 2}}
# [LightGBM] [Info] Number of positive: 36, number of negative: 604
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000609 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 758
# [LightGBM] [Info] Number of data points in the train set: 640, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.056250 -> initscore=-2.820055
# [LightGBM] [Info] Start training from score -2.820055
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
#     self._run_once()
#   File "C:\Users\U0152019\AppData\Local\miniconda3\envs\talent\lib\asyncio\base_events.py", line 1909, in _run_once
#     handle._run()
#   File "C:\Users\U0152019\AppData\Local\miniconda3\envs\talent\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\U0152019\OneDrive - KU Leuven\PhD Documents\Projects\1. TabPFN\TabPFNCredit\.venv\lib\site-packages\ipykernel\utils.py", line 71, in preserve_context
#     return await f(*args, **kwargs)
#   File "c:\Users\U0152019\OneDrive - KU Leuven\PhD Documents\Projects\1. TabPFN\TabPFNCredit\.venv\lib\site-packages\ipykernel\kernelbase.py", line 614, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "c:\Users\U0152019\OneDrive - KU Leuven\PhD Documents\Projects\1. TabPFN\TabPFNCredit\.venv\lib\site-packages\ipykernel\kernelbase.py", line 471, in dispatch_shell
#     await result
#   File "c:\Users\U0152019\OneDrive - KU Leuven\PhD Documents\Projects\1. TabPFN\TabPFNCredit\.venv\lib\site-packages\ipykernel\ipkernel.py", line 366, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\U0152019\OneDrive - KU Leuven\PhD Documents\Projects\1. TabPFN\TabPFNCredit\.venv\lib\site-packages\ipykernel\kernelbase.py", line 827, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\U0152019\OneDrive - KU Leuven\PhD Documents\Projects\1. TabPFN\TabPFNCredit\.venv\lib\site-packages\ipykernel\ipkernel.py", line 458, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\U0152019\OneDrive - KU Leuven\PhD Documents\Projects\1. TabPFN\TabPFNCredit\.venv\lib\site-packages\ipykernel\zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\U0152019\OneDrive - KU Leuven\PhD Documents\Projects\1. TabPFN\TabPFNCredit\.venv\lib\site-packages\IPython\core\interactiveshell.py", line 3077, in run_cell
#     result = self._run_cell(
#   File "c:\Users\U0152019\OneDrive - KU Leuven\PhD Documents\Projects\1. TabPFN\TabPFNCredit\.venv\lib\site-packages\IPython\core\interactiveshell.py", line 3132, in _run_cell
#     result = runner(coro)
#   File "c:\Users\U0152019\OneDrive - KU Leuven\PhD Documents\Projects\1. TabPFN\TabPFNCredit\.venv\lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\U0152019\OneDrive - KU Leuven\PhD Documents\Projects\1. TabPFN\TabPFNCredit\.venv\lib\site-packages\IPython\core\interactiveshell.py", line 3336, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\U0152019\OneDrive - KU Leuven\PhD Documents\Projects\1. TabPFN\TabPFNCredit\.venv\lib\site-packages\IPython\core\interactiveshell.py", line 3519, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\U0152019\OneDrive - KU Leuven\PhD Documents\Projects\1. TabPFN\TabPFNCredit\.venv\lib\site-packages\IPython\core\interactiveshell.py", line 3579, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\U0152019\AppData\Local\Temp\ipykernel_10848\864126987.py", line 14, in <module>
#     run_experiment1(
#   File "c:\Users\U0152019\OneDrive - KU Leuven\PhD Documents\Projects\1. TabPFN\TabPFNCredit\scripts\Experiment1.py", line 216, in run_experiment1
#     logger.info(f"✓ Completed and saved: {dataset_filename}")
# Message: '✓ Completed and saved: lgd_0001.heloc'
# Arguments: ()
# 2025-11-17 12:07:13,026 - scripts.Experiment1 - INFO - ✓ Completed and saved: lgd_0001.heloc
# 2025-11-17 12:07:13,029 - scripts.Experiment1 - INFO -
# ================================================================================
# 2025-11-17 12:07:13,029 - scripts.Experiment1 - INFO - EXPERIMENT 1 COMPLETE
# 2025-11-17 12:07:13,029 - scripts.Experiment1 - INFO - ================================================================================
# 2025-11-17 12:07:13,029 - scripts.Experiment1 - INFO - Total datasets: 2
# 2025-11-17 12:07:13,029 - scripts.Experiment1 - INFO - Completed: 2
# 2025-11-17 12:07:13,031 - scripts.Experiment1 - INFO - Skipped: 0
# 2025-11-17 12:07:13,031 - scripts.Experiment1 - INFO - Failed: 0
# 2025-11-17 12:07:13,031 - scripts.Experiment1 - INFO -
# Completed datasets:
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\U0152019\AppData\Local\miniconda3\envs\talent\lib\logging\__init__.py", line 1103, in emit
#     stream.write(msg + self.terminator)
#   File "C:\Users\U0152019\AppData\Local\miniconda3\envs\talent\lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
# UnicodeEncodeError: 'charmap' codec can't encode character '\u2713' in position 57: character maps to <undefined>
# Call stack:
#   File "C:\Users\U0152019\AppData\Local\miniconda3\envs\talent\lib\runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\U0152019\AppData\Local\miniconda3\envs\talent\lib\runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "c:\Users\U0152019\OneDrive - KU Leuven\PhD Documents\Projects\1. TabPFN\TabPFNCredit\.venv\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\U0152019\OneDrive - KU Leuven\PhD Documents\Projects\1. TabPFN\TabPFNCredit\.venv\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\U0152019\OneDrive - KU Leuven\PhD Documents\Projects\1. TabPFN\TabPFNCredit\.venv\lib\site-packages\ipykernel\kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "c:\Users\U0152019\OneDrive - KU Leuven\PhD Documents\Projects\1. TabPFN\TabPFNCredit\.venv\lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\U0152019\AppData\Local\miniconda3\envs\talent\lib\asyncio\base_events.py", line 603, in run_forever
#     self._run_once()
#   File "C:\Users\U0152019\AppData\Local\miniconda3\envs\talent\lib\asyncio\base_events.py", line 1909, in _run_once
#     handle._run()
#   File "C:\Users\U0152019\AppData\Local\miniconda3\envs\talent\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\U0152019\OneDrive - KU Leuven\PhD Documents\Projects\1. TabPFN\TabPFNCredit\.venv\lib\site-packages\ipykernel\utils.py", line 71, in preserve_context
#     return await f(*args, **kwargs)
#   File "c:\Users\U0152019\OneDrive - KU Leuven\PhD Documents\Projects\1. TabPFN\TabPFNCredit\.venv\lib\site-packages\ipykernel\kernelbase.py", line 614, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "c:\Users\U0152019\OneDrive - KU Leuven\PhD Documents\Projects\1. TabPFN\TabPFNCredit\.venv\lib\site-packages\ipykernel\kernelbase.py", line 471, in dispatch_shell
#     await result
#   File "c:\Users\U0152019\OneDrive - KU Leuven\PhD Documents\Projects\1. TabPFN\TabPFNCredit\.venv\lib\site-packages\ipykernel\ipkernel.py", line 366, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\U0152019\OneDrive - KU Leuven\PhD Documents\Projects\1. TabPFN\TabPFNCredit\.venv\lib\site-packages\ipykernel\kernelbase.py", line 827, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\U0152019\OneDrive - KU Leuven\PhD Documents\Projects\1. TabPFN\TabPFNCredit\.venv\lib\site-packages\ipykernel\ipkernel.py", line 458, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\U0152019\OneDrive - KU Leuven\PhD Documents\Projects\1. TabPFN\TabPFNCredit\.venv\lib\site-packages\ipykernel\zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\U0152019\OneDrive - KU Leuven\PhD Documents\Projects\1. TabPFN\TabPFNCredit\.venv\lib\site-packages\IPython\core\interactiveshell.py", line 3077, in run_cell
#     result = self._run_cell(
#   File "c:\Users\U0152019\OneDrive - KU Leuven\PhD Documents\Projects\1. TabPFN\TabPFNCredit\.venv\lib\site-packages\IPython\core\interactiveshell.py", line 3132, in _run_cell
#     result = runner(coro)
#   File "c:\Users\U0152019\OneDrive - KU Leuven\PhD Documents\Projects\1. TabPFN\TabPFNCredit\.venv\lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\U0152019\OneDrive - KU Leuven\PhD Documents\Projects\1. TabPFN\TabPFNCredit\.venv\lib\site-packages\IPython\core\interactiveshell.py", line 3336, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\U0152019\OneDrive - KU Leuven\PhD Documents\Projects\1. TabPFN\TabPFNCredit\.venv\lib\site-packages\IPython\core\interactiveshell.py", line 3519, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\U0152019\OneDrive - KU Leuven\PhD Documents\Projects\1. TabPFN\TabPFNCredit\.venv\lib\site-packages\IPython\core\interactiveshell.py", line 3579, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\U0152019\AppData\Local\Temp\ipykernel_10848\864126987.py", line 14, in <module>
#     run_experiment1(
#   File "c:\Users\U0152019\OneDrive - KU Leuven\PhD Documents\Projects\1. TabPFN\TabPFNCredit\scripts\Experiment1.py", line 234, in run_experiment1
#     logger.info(f"  ✓ {ds}")
# Message: '  ✓ pd_0001.gmsc'
# Arguments: ()
# 2025-11-17 12:07:13,031 - scripts.Experiment1 - INFO -   ✓ pd_0001.gmsc
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\U0152019\AppData\Local\miniconda3\envs\talent\lib\logging\__init__.py", line 1103, in emit
#     stream.write(msg + self.terminator)
#   File "C:\Users\U0152019\AppData\Local\miniconda3\envs\talent\lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
# UnicodeEncodeError: 'charmap' codec can't encode character '\u2713' in position 57: character maps to <undefined>
# Call stack:
#   File "C:\Users\U0152019\AppData\Local\miniconda3\envs\talent\lib\runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\U0152019\AppData\Local\miniconda3\envs\talent\lib\runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "c:\Users\U0152019\OneDrive - KU Leuven\PhD Documents\Projects\1. TabPFN\TabPFNCredit\.venv\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\U0152019\OneDrive - KU Leuven\PhD Documents\Projects\1. TabPFN\TabPFNCredit\.venv\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\U0152019\OneDrive - KU Leuven\PhD Documents\Projects\1. TabPFN\TabPFNCredit\.venv\lib\site-packages\ipykernel\kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "c:\Users\U0152019\OneDrive - KU Leuven\PhD Documents\Projects\1. TabPFN\TabPFNCredit\.venv\lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\U0152019\AppData\Local\miniconda3\envs\talent\lib\asyncio\base_events.py", line 603, in run_forever
#     self._run_once()
#   File "C:\Users\U0152019\AppData\Local\miniconda3\envs\talent\lib\asyncio\base_events.py", line 1909, in _run_once
#     handle._run()
#   File "C:\Users\U0152019\AppData\Local\miniconda3\envs\talent\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\U0152019\OneDrive - KU Leuven\PhD Documents\Projects\1. TabPFN\TabPFNCredit\.venv\lib\site-packages\ipykernel\utils.py", line 71, in preserve_context
#     return await f(*args, **kwargs)
#   File "c:\Users\U0152019\OneDrive - KU Leuven\PhD Documents\Projects\1. TabPFN\TabPFNCredit\.venv\lib\site-packages\ipykernel\kernelbase.py", line 614, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "c:\Users\U0152019\OneDrive - KU Leuven\PhD Documents\Projects\1. TabPFN\TabPFNCredit\.venv\lib\site-packages\ipykernel\kernelbase.py", line 471, in dispatch_shell
#     await result
#   File "c:\Users\U0152019\OneDrive - KU Leuven\PhD Documents\Projects\1. TabPFN\TabPFNCredit\.venv\lib\site-packages\ipykernel\ipkernel.py", line 366, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\U0152019\OneDrive - KU Leuven\PhD Documents\Projects\1. TabPFN\TabPFNCredit\.venv\lib\site-packages\ipykernel\kernelbase.py", line 827, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\U0152019\OneDrive - KU Leuven\PhD Documents\Projects\1. TabPFN\TabPFNCredit\.venv\lib\site-packages\ipykernel\ipkernel.py", line 458, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\U0152019\OneDrive - KU Leuven\PhD Documents\Projects\1. TabPFN\TabPFNCredit\.venv\lib\site-packages\ipykernel\zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\U0152019\OneDrive - KU Leuven\PhD Documents\Projects\1. TabPFN\TabPFNCredit\.venv\lib\site-packages\IPython\core\interactiveshell.py", line 3077, in run_cell
#     result = self._run_cell(
#   File "c:\Users\U0152019\OneDrive - KU Leuven\PhD Documents\Projects\1. TabPFN\TabPFNCredit\.venv\lib\site-packages\IPython\core\interactiveshell.py", line 3132, in _run_cell
#     result = runner(coro)
#   File "c:\Users\U0152019\OneDrive - KU Leuven\PhD Documents\Projects\1. TabPFN\TabPFNCredit\.venv\lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\U0152019\OneDrive - KU Leuven\PhD Documents\Projects\1. TabPFN\TabPFNCredit\.venv\lib\site-packages\IPython\core\interactiveshell.py", line 3336, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\U0152019\OneDrive - KU Leuven\PhD Documents\Projects\1. TabPFN\TabPFNCredit\.venv\lib\site-packages\IPython\core\interactiveshell.py", line 3519, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\U0152019\OneDrive - KU Leuven\PhD Documents\Projects\1. TabPFN\TabPFNCredit\.venv\lib\site-packages\IPython\core\interactiveshell.py", line 3579, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\U0152019\AppData\Local\Temp\ipykernel_10848\864126987.py", line 14, in <module>
#     run_experiment1(
#   File "c:\Users\U0152019\OneDrive - KU Leuven\PhD Documents\Projects\1. TabPFN\TabPFNCredit\scripts\Experiment1.py", line 234, in run_experiment1
#     logger.info(f"  ✓ {ds}")
# Message: '  ✓ lgd_0001.heloc'
# Arguments: ()
# 2025-11-17 12:07:13,034 - scripts.Experiment1 - INFO -   ✓ lgd_0001.heloc
# 2025-11-17 12:07:13,036 - scripts.Experiment1 - INFO -
# Results saved to: C:\Users\U0152019\OneDrive - KU Leuven\PhD Documents\Projects\1. TabPFN\TabPFNCredit\results\experiment1
# 2025-11-17 12:07:13,036 - scripts.Experiment1 - INFO - HPO configs saved to: C:\Users\U0152019\OneDrive - KU Leuven\PhD Documents\Projects\1. TabPFN\TabPFNCredit\results\experiment1\config_hpo
# 2025-11-17 12:07:13,036 - scripts.Experiment1 - INFO - Log file: C:\Users\U0152019\OneDrive - KU Leuven\PhD Documents\Projects\1. TabPFN\TabPFNCredit\results\experiment1\experiment1.log
# 2025-11-17 12:07:13,037 - scripts.Experiment1 - INFO - ================================================================================
# Test: loss=0.0534
# [MAE]=0.0188
# [R2]=0.9459
# [RMSE]=0.1021
# Time cost: 0.1590s
#
# Fold 5 results:
#   MAE: 0.0188
#   R2: 0.9459
#   RMSE: 0.1021
#
# ======================================================================
# Completed 5 folds for PFN-v2
# ======================================================================
#
#
# ================================================================================
# HPO comparison complete for 0001.heloc
# Methods evaluated: ['catboost', 'knn', 'lightgbm', 'LinearRegression', 'RandomForest', 'xgboost', 'svm', 'mlp', 'tabnet', 'PFN-v2']
# ================================================================================
